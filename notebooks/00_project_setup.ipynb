# %% [markdown]
# <a href="https://colab.research.google.com/github/ArghyaRC96/metricguard-ai/blob/main/notebooks/00_project_setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🛡️ MetricGuard AI — Project Setup
#
# ## Conflict-Aware, Version-Aware Agentic RAG for Analytics Governance
#
# MetricGuard AI is a production-style Retrieval-Augmented Generation (RAG)
# and Agentic AI system designed to investigate analytics metric discrepancies.
#
# The system will combine:
#
# - document ingestion and parsing
# - metadata-aware retrieval
# - metric version tracking
# - freshness detection
# - SQL lineage analysis
# - downstream impact analysis
# - conflict detection
# - multi-agent investigation
# - source-grounded answers
# - confidence scoring
# - audit logging
# - role-based access control
#
# ---
#
# ### Notebook Purpose
#
# This notebook initializes and validates the development environment for the
# MetricGuard AI project.
#
# No production business logic will live permanently in this notebook.
# Reusable implementation will later be moved into `src/metricguard/`.

# %%
import sys
import platform
import os

print("MetricGuard AI - Environment Check")
print("-" * 50)

print(f"Python version : {sys.version}")
print(f"Platform       : {platform.platform()}")
print(f"Working dir    : {os.getcwd()}")
# Out:
# MetricGuard AI - Environment Check
# --------------------------------------------------
# Python version : 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# Platform       : Linux-6.6.122+-x86_64-with-glibc2.35
# Working dir    : /content

# %%
PROJECT_NAME = "metricguard-ai"
PROJECT_DISPLAY_NAME = "MetricGuard AI"
PROJECT_VERSION = "0.1.0"

print(f"Project : {PROJECT_DISPLAY_NAME}")
print(f"Repo    : {PROJECT_NAME}")
print(f"Version : {PROJECT_VERSION}")
# Out:
# Project : MetricGuard AI
# Repo    : metricguard-ai
# Version : 0.1.0

# %% [markdown]
# ## Development Strategy
#
# MetricGuard AI follows a notebook-to-production workflow.
#
# ```text
# Google Colab
#     ↓
# Experiment and validate
#     ↓
# Reusable logic identified
#     ↓
# src/metricguard/
#     ↓
# Production-style Python modules
#     ↓
# Tests
#     ↓
# Streamlit application
#
# ### Repository Responsibilities
#
# - `notebooks/` — experimentation and development
# - `src/metricguard/` — reusable application logic
# - `data/raw/` — original source documents
# - `data/processed/` — automatically generated processed artifacts
# - `data/ground_truth/` — evaluation truth for the synthetic benchmark
# - `tests/` — automated software tests
# - `configs/` — application configuration
# - `docs/` — architecture, screenshots, and evaluation documentation
# - `app/` — Streamlit interface
# - `outputs/` — generated experiment and evaluation outputs
